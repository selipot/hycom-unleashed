# %% [markdown]
# # Code to release particles in HYCOM, multifiles, Equator for 30 days, forward

# %%
# parcels
from parcels import VectorField, Field, SummedField, FieldSet, ParticleSet, Variable, ScipyParticle, JITParticle, AdvectionRK4, plotTrajectoriesFile, ParcelsRandom, ErrorCode

# open data to validate
from netCDF4 import Dataset
from glob import glob

# others
import numpy as np
import numpy.matlib
from datetime import timedelta, datetime
import xarray as xr
import os

# plotting
import matplotlib.pyplot as plt
from matplotlib import rc
from mpl_toolkits.axes_grid1 import make_axes_locatable
import cartopy.feature as cfeature
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
# %matplotlib inline

# %%
# create list of files; that's from 1_01 to 99_23, why not
dirin = '/projects2/rsmas/tidaldrift/hycom/'
uvfiles = dirin + '102_archv.2014_0*_*_uv_0+15m.nc'
sshfiles = dirin + '102_archs.2014_0*_*_ssh_0m.nc'

# %%
ds1 = xr.open_dataset(dirin+'102_archv.2014_001_01_uv_0+15m.nc')
ds1
# Out:
# <xarray.Dataset>
# Dimensions:    (MT: 1, Depth: 2, Y: 7055, X: 9000)
# Coordinates:
#   * MT         (MT) datetime64[ns] 2014-01-01T01:00:28.800000
#     Date       (MT) float64 ...
#   * Depth      (Depth) float32 0.0 15.0
#   * Y          (Y) int32 1 2 3 4 5 6 7 8 ... 7049 7050 7051 7052 7053 7054 7055
#   * X          (X) int32 1 2 3 4 5 6 7 8 ... 8994 8995 8996 8997 8998 8999 9000
#     Latitude   (Y, X) float32 ...
#     Longitude  (Y, X) float32 ...
# Data variables:
#     u          (MT, Depth, Y, X) float32 ...
#     bot_u      (MT, Y, X) float32 ...
#     v          (MT, Depth, Y, X) float32 ...
#     bot_v      (MT, Y, X) float32 ...
# Attributes:
#     Conventions:  CF-1.0
#     title:        HYCOM
#     source:       HYCOM archive file
#     experiment:   10.2
#     history:      archv2ncdf3z

# %%
ds2 = xr.open_dataset(dirin+'102_archs.2014_001_01_ssh_0m.nc')
ds2
# Out:
# <xarray.Dataset>
# Dimensions:        (MT: 1, Y: 7055, X: 9000)
# Coordinates:
#   * MT             (MT) datetime64[ns] 2014-01-01T01:00:00
#     Date           (MT) float64 ...
#   * Y              (Y) int32 1 2 3 4 5 6 7 ... 7050 7051 7052 7053 7054 7055
#   * X              (X) int32 1 2 3 4 5 6 7 ... 8995 8996 8997 8998 8999 9000
#     Latitude       (Y, X) float32 ...
#     Longitude      (Y, X) float32 ...
# Data variables:
#     steric_ssh     (MT, Y, X) float32 ...
#     nonsteric_ssh  (MT, Y, X) float32 ...
#     ssh            (MT, Y, X) float32 ...
# Attributes:
#     Conventions:  CF-1.0
#     title:        HYCOM
#     source:       HYCOM archive file
#     experiment:   10.2
#     history:      archv2ncdf2d

# %%
# create a dictionary 
filenames1 = {'U': uvfiles,
             'V': uvfiles}
filenames2 = {'SSH': sshfiles}

# map u, v, to the names in the velocity files
variables1 = {'U': 'u',
             'V': 'v'}
variables2 = {'SSH' : 'ssh'}

# map lon, lat, depth, time to the names in the velocity files
dimensions1 = {'depth':'Depth',
              'lon': 'Longitude',
              'lat': 'Latitude'
              }
dimensions2 = {'lon': 'Longitude',
              'lat': 'Latitude'
              }
# but is it going to be sorted?
display(filenames1)
display(filenames2)
# Out:
# {'U': '/projects2/rsmas/tidaldrift/hycom/102_archv.2014_0*_*_uv_0+15m.nc',
#  'V': '/projects2/rsmas/tidaldrift/hycom/102_archv.2014_0*_*_uv_0+15m.nc'}
# {'SSH': '/projects2/rsmas/tidaldrift/hycom/102_archs.2014_0*_*_ssh_0m.nc'}

# %%
# select one layer (0 for surface, 1 for 15m deep)
indices = {'depth': [0]}

# %%
# not needed, see below?
# timestamps = np.expand_dims(np.array([np.datetime64('2014-01-01T%.2d:00:00' %m) 
#                                      for m in range(1,24)]), axis=1)
#timestamps = np.expand_dims(np.array(np.datetime64('2014-01-01T01:00:00')),axis=0)
timestamps = np.expand_dims(np.arange('2014-01-01T01', '2014-04-10T00', dtype='datetime64[h]'),axis=1)

# %%
print(len(filenames2))
print(len(timestamps))
# Out:
# 1
# 2375

# %%
# define the first "Fieldset" from velocity files
fieldset = FieldSet.from_netcdf(filenames1, variables1, dimensions1, indices, mesh='spherical',
                                 allow_time_extrapolation=False,deferred_load=True,timestamps=timestamps)
# fieldset = FieldSet.from_netcdf(filenames, variables, dimensions, indices, mesh='spherical',
#                                  allow_time_extrapolation=False,deferred_load=True)

# %%
filenames2.keys()
# Out:
# dict_keys(['SSH'])

# %%
# create an extra field for SSH
sshfieldset = FieldSet.from_netcdf(filenames2,variables2,dimensions2,mesh='spherical',
                                 allow_time_extrapolation=False,deferred_load=True,timestamps=timestamps)

# %%
fieldset.add_field(sshfieldset.SSH)

# %%
display(fieldset.U.dimensions)
display(fieldset.U.indices)
display(fieldset.SSH.dimensions)
display(fieldset.SSH.indices)
# Out:
# {'depth': 'Depth', 'lon': 'Longitude', 'lat': 'Latitude'}
# {'depth': [0], 'lon': range(0, 9000), 'lat': range(0, 7055)}
# {'lon': 'Longitude', 'lat': 'Latitude'}
# {'lon': range(0, 9000), 'lat': range(0, 7055), 'depth': [0]}

# %%
# define a new field, X, which will be used to implement cyclic boundary conditions
X = numpy.matlib.repmat(np.arange(1,9001,dtype=float), 7055, 1)
X = np.expand_dims(X, axis=0)
X = np.expand_dims(X, axis=0)
display(np.shape(X))
display(X[-1,-1])
# Out:
# (1, 1, 7055, 9000)
# array([[1.000e+00, 2.000e+00, 3.000e+00, ..., 8.998e+03, 8.999e+03,
#         9.000e+03],
#        [1.000e+00, 2.000e+00, 3.000e+00, ..., 8.998e+03, 8.999e+03,
#         9.000e+03],
#        [1.000e+00, 2.000e+00, 3.000e+00, ..., 8.998e+03, 8.999e+03,
#         9.000e+03],
#        ...,
#        [1.000e+00, 2.000e+00, 3.000e+00, ..., 8.998e+03, 8.999e+03,
#         9.000e+03],
#        [1.000e+00, 2.000e+00, 3.000e+00, ..., 8.998e+03, 8.999e+03,
#         9.000e+03],
#        [1.000e+00, 2.000e+00, 3.000e+00, ..., 8.998e+03, 8.999e+03,
#         9.000e+03]])

# %%
fieldset.SSH.depth
# Out:
# array([0.], dtype=float32)

# %%
F = Field('X',X,lon=fieldset.U.lon,lat=fieldset.U.lat,depth=fieldset.SSH.depth,allow_time_extrapolation=True,
          time=np.ones(1) * timedelta(seconds=int(30*24*60*60)).total_seconds())
#F = Field('X',X,lon=fieldset.SSH.lon,lat=fieldset.SSH.lat)

# %%
fieldset.add_field(F)

# %%
# why none for X?
display(fieldset.X.dimensions)
display(fieldset.U.dimensions)
display(fieldset.SSH.dimensions)
# Out:
# None
# {'depth': 'Depth', 'lon': 'Longitude', 'lat': 'Latitude'}
# {'lon': 'Longitude', 'lat': 'Latitude'}

# %%
display(fieldset.SSH.data.data_shape)
display(fieldset.U.data.data_shape)
display(fieldset.X.data.shape)
# Out:
# (2375, 1, 7055, 9000)
# (2375, 1, 7055, 9000)
# (1, 7055, 9000)

# %%
print(fieldset.time_origin)

print(fieldset.U.dimensions)
print(fieldset.U.indices)
print(fieldset.U.creation_log)
print(fieldset.U.grid.time)

print(fieldset.SSH.dimensions)
print(fieldset.SSH.indices)
print(fieldset.SSH.creation_log)
print(fieldset.SSH.grid.time)

print(fieldset.X.dimensions)
print(fieldset.X.indices)
print(fieldset.X.creation_log)
print(fieldset.X.grid.time)
# Out:
# 2014-01-01T01
# {'depth': 'Depth', 'lon': 'Longitude', 'lat': 'Latitude'}
# {'depth': [0], 'lon': range(0, 9000), 'lat': range(0, 7055)}
# from_netcdf
# [0.0000e+00 3.6000e+03 7.2000e+03 ... 8.5392e+06 8.5428e+06 8.5464e+06]
# {'lon': 'Longitude', 'lat': 'Latitude'}
# {'lon': range(0, 9000), 'lat': range(0, 7055), 'depth': [0]}
# from_netcdf
# [0.0000e+00 3.6000e+03 7.2000e+03 ... 8.5392e+06 8.5428e+06 8.5464e+06]
# None
# None
#
# [2592000.]

# %%
fieldset.X.dimensions = fieldset.U.dimensions
fieldset.X.indices = fieldset.U.indices

# %%
print(fieldset.U.dimensions)
print(fieldset.U.indices)
print(fieldset.SSH.dimensions)
print(fieldset.SSH.indices)
print(fieldset.X.dimensions)
print(fieldset.X.indices)
print(fieldset.X.interp_method)
# Out:
# {'depth': 'Depth', 'lon': 'Longitude', 'lat': 'Latitude'}
# {'depth': [0], 'lon': range(0, 9000), 'lat': range(0, 7055)}
# {'lon': 'Longitude', 'lat': 'Latitude'}
# {'lon': range(0, 9000), 'lat': range(0, 7055), 'depth': [0]}
# {'depth': 'Depth', 'lon': 'Longitude', 'lat': 'Latitude'}
# {'depth': [0], 'lon': range(0, 9000), 'lat': range(0, 7055)}
# linear

# %%
# create a particle set along equator
t0 = 30*24*60*60 # time of the release [s]
plon = np.arange(-180,180)
plat = np.ones_like(plon) * 0
ptime = np.ones(len(plon)) * timedelta(seconds=int(t0)).total_seconds()
len(ptime)
# Out:
# 360

# %%
# time can be set with the time= parameters
# but by default the particle will be release at
# the first time of the fieldset
pset = ParticleSet.from_list(fieldset=fieldset,         # fieldset
                             pclass=JITParticle,        # type of particles
                             #repeatdt=adv_reinject_dt, # relaunch freq
                             lon=plon,                  # release lon
                             lat=plat,                  # release lat
                             time=ptime)                # release time

# %%
# pset.show(show_time=0,domain={'N':20, 'S':-20, 'E':179, 'W':360-179})

# %%
display(pset[0],pset[-1])
# Out:
# P[0](lon=-180.000000, lat=0.000000, depth=0.000000, time=2592000.000000)
# P[359](lon=179.000000, lat=0.000000, depth=0.000000, time=2592000.000000)

# %%
class SampleParticleInitZero(JITParticle):            # Define a new particle class
    ssh = Variable('SSH', initial=0)                  # Variable 'SSH' initially zero
    #u = Variable('U', initial=0)                      # Variable 'U','V' initially zero
    #v = Variable('V', initial=0)                      # Variable 'U','V' initially zero    
    x = Variable('X',initial=0)

# %%
pset = ParticleSet(fieldset=fieldset, pclass=SampleParticleInitZero, lon=plon, lat=plat, time=ptime)
display(pset[0],pset[-1])
# Out:
# P[360](lon=-180.000000, lat=0.000000, depth=0.000000, SSH=0.000000, X=0.000000, time=2592000.000000)
# P[719](lon=179.000000, lat=0.000000, depth=0.000000, SSH=0.000000, X=0.000000, time=2592000.000000)

# %%
def Sample(particle, fieldset, time):
         particle.SSH = fieldset.SSH[time, particle.depth, particle.lat, particle.lon]
         particle.X = fieldset.X[time,particle.depth, particle.lat, particle.lon]        
         #particle.U = fieldset.U[time, particle.depth, particle.lat, particle.lon]
         #particle.V = fieldset.V[time, particle.depth, particle.lat, particle.lon]    
sample_kernel = pset.Kernel(Sample)    # Casting the Sample function to a kernel.

# %%
# function to delete particle when out of bounds
def DeleteParticle(particle, fieldset, time):
    particle.delete()

# %%
# below fails but works if I remove above the X sampling. 
pset.execute(sample_kernel, dt=0)
# Out:
# sh: None: command not found
# INFO: Compiled ArraySampleParticleInitZeroSample ==> /tmp/parcels-3477/libd137f9d782228f71cd8b257c60d7d7f0_0.so
# WARNING: dt or runtime are zero, or endtime is equal to Particle.time. The kernels will be executed once, without incrementing time
# Correct cell not found for (-180.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -6.3672140672782871e+03 1.0000000000000000e+00
# Correct cell not found for (-179.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -6.3421620795107037e+03 1.0000000000000000e+00
# Correct cell not found for (-178.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -6.3171100917431195e+03 1.0000000000000000e+00
# Correct cell not found for (-177.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -6.2920581039755352e+03 1.0000000000000000e+00
# Correct cell not found for (-176.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -6.2670061162079510e+03 1.0000000000000000e+00
# Correct cell not found for (-175.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -6.2419541284403667e+03 1.0000000000000000e+00
# Correct cell not found for (-174.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -6.2169021406727825e+03 1.0000000000000000e+00
# Correct cell not found for (-173.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta)
000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -8.3072477064220186e+02 1.0000000000000000e+00
# Correct cell not found for (42.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -8.0567278287461772e+02 1.0000000000000000e+00
# Correct cell not found for (43.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -7.8062079510703359e+02 1.0000000000000000e+00
# Correct cell not found for (44.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -7.5556880733944956e+02 1.0000000000000000e+00
# Correct cell not found for (45.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -7.3051681957186543e+02 1.0000000000000000e+00
# Correct cell not found for (46.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -7.0546483180428129e+02 1.0000000000000000e+00
# Correct cell not found for (47.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -6.8041284403669727e+02 1.0000000000000000e+00
# Correct cell not found for (48.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -6.5536085626911313e+02 1.0000000000000000e+00
# Correct cell not found for (49.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -6.3030886850152910e+02 1.0000000000000000e+00
# Correct cell not found for (50.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -6.0525688073394497e+02 1.0000000000000000e+00
# Correct cell not found for (51.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -5.8020489296636083e+02 1.0000000000000000e+00
# Correct cell not found for (52.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -5.5515290519877681e+02 1.0000000000000000e+00
# Correct cell not found for (53.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -5.3010091743119267e+02 1.0000000000000000e+00
# Correct cell not found for (54.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -5.0504892966360859e+02 1.0000000000000000e+00
# Correct cell not found for (55.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -4.7999694189602445e+02 1.0000000000000000e+00
# Correct cell not found for (56.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -4.5494495412844037e+02 1.0000000000000000e+00
# Correct cell not found for (57.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -4.2989296636085629e+02 1.0000000000000000e+00
# Correct cell not found for (58.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -4.0484097859327215e+02 1.0000000000000000e+00
# Correct cell not found for (59.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -3.7978899082568807e+02 1.0000000000000000e+00
# Correct cell not found for (60.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -3.5473700305810399e+02 1.0000000000000000e+00
# Correct cell not found for (61.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -3.2968501529051986e+02 1.0000000000000000e+00
# Correct cell not found for (62.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -3.0463302752293578e+02 1.0000000000000000e+00
# Correct cell not found for (63.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -2.7958103975535170e+02 1.0000000000000000e+00
# Correct cell not found for (64.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -2.5452905198776759e+02 1.0000000000000000e+00
# Correct cell not found for (65.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -2.2947706422018348e+02 1.0000000000000000e+00
# Correct cell not found for (66.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -2.0442507645259940e+02 1.0000000000000000e+00
# Correct cell not found for (67.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -1.7937308868501529e+02 1.0000000000000000e+00
# Correct cell not found for (68.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -1.5432110091743118e+02 1.0000000000000000e+00
# Correct cell not found for (69.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -1.2926911314984710e+02 1.0000000000000000e+00
# Correct cell not found for (70.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -1.0421712538226299e+02 1.0000000000000000e+00
# Correct cell not found for (71.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -7.9165137614678898e+01 1.0000000000000000e+00
# Correct cell not found for (72.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -5.4113149847094803e+01 1.0000000000000000e+00
# Correct cell not found for (73.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -2.9061162079510705e+01 1.0000000000000000e+00
# Correct cell not found for (74.000000, 0.000000) after 1000000 iterations
# Debug info: old particle indices: (yi, xi) 0 0
#             new particle indices: (yi, xi) 3467 0
#             Mesh 2d shape:  7055 9000
#             Relative particle position:  (xsi, eta) -4.0091743119266052e+00 1.0000000000000000e+00
# ---------------------------------------------------------------------------
# OutOfBoundsError                          Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 # below fails but works if I remove above the X sampling.
# ----> 2 pset.execute(sample_kernel, dt=0)
#
# File ~/miniconda3/envs/py3_parcels/lib/python3.8/site-packages/parcels-2.3.1.dev129+g65e5d595-py3.8.egg/parcels/particleset/baseparticleset.py:452, in BaseParticleSet.execute(self, pyfunc, pyfunc_inter, endtime, runtime, dt, moviedt, recovery, output_file, movie_background_field, verbose_progress, postIterationCallbacks, callbackdt)
#     450 # If we don't perform interaction, only execute the normal kernel efficiently.
#     451 if self.interaction_kernel is None:
# --> 452     self.kernel.execute(self, endtime=next_time, dt=dt, recovery=recovery, output_file=output_file,
#     453                         execute_once=execute_once)
#     454 # Interaction: interleave the interaction and non-interaction kernel for each time step.
#     455 # E.g. Inter -> Normal -> Inter -> Normal if endtime-time == 2*dt
#     456 else:
#     457     cur_time = time
#
# File ~/miniconda3/envs/py3_parcels/lib/python3.8/site-packages/parcels-2.3.1.dev129+g65e5d595-py3.8.egg/parcels/kernel/kernelsoa.py:227, in KernelSOA.execute(self, pset, endtime, dt, recovery, output_file, execute_once)
#     225 recovery_kernel = recovery_map[p.state]
#     226 p.set_state(StateCode.Success)
# --> 227 recovery_kernel(p, self.fieldset, p.time)
#     228 if p.isComputed():
#     229     p.reset_state()
#
# File ~/miniconda3/envs/py3_parcels/lib/python3.8/site-packages/parcels-2.3.1.dev129+g65e5d595-py3.8.egg/parcels/tools/statuscodes.py:196, in recovery_kernel_out_of_bounds(particle, fieldset, time)
#     192 """Default sampling error kernel that throws OutOfBoundsError"""
#     193 if particle.exception is None:
#     194     # TODO: JIT does not yet provide the context that created
#     195     # the exception. We need to pass that info back from C.
# --> 196     raise OutOfBoundsError(particle, fieldset)
#     197 else:
#     198     error = particle.exception
#
# OutOfBoundsError: 0
# Particle P[360](lon=-180.000000, lat=0.000000, depth=0.000000, SSH=0.000000, X=0.000000, time=2592000.000000)
# Time: 2014-01-31T01:00:00,	timestep dt: -0.000000
# Out-of-bounds sampling by particle at (-180.000000, 0.000000, 0.000000)

# %%
fieldset.X.grid.time

# %%
#units? m per nanoseconds?
plt.plot(pset.V)

# %%
# advection parameters
runtime = timedelta(days=1)                     # advection integration time
dt = timedelta(minutes=20)                       # advection timestep: what should it be compared to time step of fields (1h?)
#dt = timedelta(hours=1)                       # advection timestep: what should it be compared to time step of fields (1h?)
outputdt = timedelta(hours=1)                    # output frequency
outfile = 'test_to_delete.nc'
# output files for the trajectories
output_file = pset.ParticleFile(name=outfile, outputdt=outputdt)

# %%
# del kernel
kernel1 = pset.Kernel(AdvectionRK4)

# %%
# do not forget to set this up before!export CC=gcc on macOS

# %%
# execute the integration
# %time
pset.execute(kernel1 + sample_kernel,# + kernel2 + sample_kernel,          # the kernels (define how particles move)
     runtime=runtime,                         # the total length of the run
     dt=dt,                                   # the timestep of the kernel
     recovery={ErrorCode.ErrorOutOfBounds: DeleteParticle},
     output_file=output_file)

# %%
#os.system("parcels_convert_npydir_to_netcdf out-YYSVJCKA")
output_file.export()
